# %%
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook

# %% [markdown]
# # 同一組資料 SGD

# %%
class SGD_ASGD_linear():
  
    def train(self,epoch,n,dim,lr,alpha,param_fix=True):

        if param_fix:
            np.random.seed(2021)
            self.true_theta = np.random.randn(dim)
            np.random.seed()
        else:
            self.true_theta = np.random.randn(dim)
        
        self.x = np.random.normal(loc=5,scale=1,size=(n,dim))
        self.y = np.dot(self.x,self.true_theta)+np.random.randn()
        
        self.SGD = list()
        self.ASGD = list()
        
        
        for m in tqdm_notebook(range(epoch)):
            
            self.theta_hat =[]
            theta_hat = np.random.randn(len(self.true_theta))
            
            sample = np.random.choice(a=range(n),size=n,replace=True)
            
            count = 0
            for i in sample:    
                
                lr_now = lr*pow(count+1,-alpha)

                coef = np.linalg.inv(np.eye(dim)+lr_now*np.dot(self.x[i].reshape(dim,-1),self.x[i].reshape(-1,dim)))

                theta_hat = np.dot(coef,theta_hat) + np.dot(coef,lr_now*self.y[i]*self.x[i])

                self.theta_hat.append(theta_hat)
                count += 1

            self.SGD.append(self.theta_hat[-1])
            self.ASGD.append(np.mean(self.theta_hat,axis=0))

# %%
n = 10000
dim = 5
lr = 10
alpha = 0.6
epoch = 100

# %%
result = SGD_ASGD_linear()
result.train(epoch,n,dim,lr,alpha)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
result.true_theta
# Out:
# array([ 1.48860905,  0.67601087, -0.41845137, -0.80652081,  0.55587583])

# %%
result.ASGD
# Out:
# [array([ 1.4606887 ,  0.64983635, -0.41095248, -0.80261235,  0.52876555]),
#  array([ 1.46188696,  0.67041164, -0.43328604, -0.80456842,  0.53005757]),
#  array([ 1.44843661,  0.66339414, -0.41178278, -0.81117386,  0.5365923 ]),
#  array([ 1.45288068,  0.6658784 , -0.41170425, -0.82766716,  0.54573448]),
#  array([ 1.45233035,  0.65113576, -0.42517186, -0.82101148,  0.56802584]),
#  array([ 1.44945409,  0.66236936, -0.43630358, -0.78725928,  0.53660035]),
#  array([ 1.47244159,  0.6742518 , -0.44858746, -0.81394112,  0.54141276]),
#  array([ 1.45413426,  0.66194797, -0.4115521 , -0.81260586,  0.53358167]),
#  array([ 1.45087285,  0.6608614 , -0.41813672, -0.80003225,  0.53326771]),
#  array([ 1.46123332,  0.64642335, -0.40626821, -0.83118654,  0.55519983]),
#  array([ 1.44786576,  0.67673993, -0.42921382, -0.81470116,  0.54459601]),
#  array([ 1.47018517,  0.66373622, -0.42703712, -0.81220086,  0.53068677]),
#  array([ 1.47482695,  0.64953238, -0.42078506, -0.81244093,  0.53459369]),
#  array([ 1.43900497,  0.66739875, -0.38933286, -0.81944122,  0.52791771]),
#  array([ 1.47050473,  0.65439414, -0.40962789, -0.81572096,  0.52664132]),
#  array([ 1.44432749,  0.66730381, -0.41020809, -0.80100494,  0.52456709]),
#  array([ 1.46901626,  0.63098838, -0.40609126, -0.79099623,  0.52286946]),
#  array([ 1.478525  ,  0.6484009 , -0.42359831, -0.79246272,  0.51476779]),
#  array([ 1.46400447,  0.65126899, -0.43149252, -0.79586746,  0.53824395]),
#  array([ 1.46417374,  0.66823349, -0.42477803, -0.80796367,  0.52545358]),
#  array([ 1.45611185,  0.64998445, -0.42724853, -0.80350784,  0.54940812]),
#  array([ 1.46021792,  0.64643062, -0.42964476, -0.80651917,  0.55540752]),
#  array([ 1.46125857,  0.67902036, -0.41996591, -0.82457762,  0.52912687]),
#  array([ 1.47973649,  0.65234975, -0.42098233, -0.81902739,  0.5330165 ]),
#  array([ 1.48138096,  0.6639725 , -0.43187641, -0.81134156,  0.52330415]),
#  array([ 1.46039177,  0.65956769, -0.42538529, -0.80572896,  0.53660458]),
#  array([ 1.4597416 ,  0.65811126, -0.45350505, -0.79052656,  0.55035481])]

# %%
10000*pd.DataFrame(result.ASGD).cov()
# Out:
#           0         1         2         3         4
# 0  1.803201 -0.592252 -0.456632 -0.087623 -0.667225
# 1 -0.592252  1.406390 -0.210245 -0.390039 -0.226269
# 2 -0.456632 -0.210245  1.533317 -0.511766 -0.342503
# 3 -0.087623 -0.390039 -0.511766  1.244869 -0.260875
# 4 -0.667225 -0.226269 -0.342503 -0.260875  1.505280

# %%
true = np.repeat(5,5)
true= true.reshape(5,1)
true = np.dot(true,true.T)
true = true + np.eye(5)
true = np.linalg.inv(true)

# %%
true
# Out:
# array([[ 0.8015873, -0.1984127, -0.1984127, -0.1984127, -0.1984127],
#        [-0.1984127,  0.8015873, -0.1984127, -0.1984127, -0.1984127],
#        [-0.1984127, -0.1984127,  0.8015873, -0.1984127, -0.1984127],
#        [-0.1984127, -0.1984127, -0.1984127,  0.8015873, -0.1984127],
#        [-0.1984127, -0.1984127, -0.1984127, -0.1984127,  0.8015873]])

# %% [markdown]
# # 每次生成新資料

# %%
class SGD_ASGD_linear2():
    
    def train(self,epoch,n,dim,lr,alpha,param_fix=True):
        if param_fix:
            np.random.seed(2021)
            self.true_theta = np.random.randn(dim)
            np.random.seed()
        else:
            self.true_theta = np.random.randn(dim)

        self.SGD = list()
        self.ASGD = list()

        for m in tqdm_notebook(range(epoch)):

            self.theta_hat =[]
            theta_hat = np.random.randn(len(self.true_theta))
            for i in range(n):

                lr_now = lr*pow(i+1,-alpha)
                x = np.random.normal(loc=5,scale=1,size=dim)
                y = np.dot(self.true_theta,x)+np.random.randn()
                coef = np.linalg.inv(np.eye(dim)+lr_now*np.dot(x.reshape(dim,-1),x.reshape(-1,dim)))
                
                theta_hat = np.dot(coef,theta_hat) + np.dot(coef,lr_now*y*x)
                self.theta_hat.append(theta_hat)

            self.SGD.append(self.theta_hat[-1])
            self.ASGD.append(np.mean(self.theta_hat,axis=0))

# %%
n = 10000
dim = 5
lr = 10
alpha = 0.6
epoch = 100

# %%
result2 = SGD_ASGD_linear2()
result2.train(epoch,n,dim,lr,alpha)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
result2.true_theta
# Out:
# array([ 1.48860905,  0.67601087, -0.41845137, -0.80652081,  0.55587583])

# %%
result2.ASGD
# Out:
# [array([ 1.47838244,  0.68242835, -0.42028369, -0.79244566,  0.54615091]),
#  array([ 1.48030308,  0.68272167, -0.39883872, -0.80693364,  0.5422275 ]),
#  array([ 1.46683229,  0.64505398, -0.35928953, -0.80912837,  0.5504712 ]),
#  array([ 1.50009944,  0.66733561, -0.42141969, -0.79744631,  0.5500906 ]),
#  array([ 1.48433758,  0.68164743, -0.44458703, -0.81226765,  0.58474996]),
#  array([ 1.47767452,  0.67839206, -0.40651536, -0.78635135,  0.53036123]),
#  array([ 1.47934756,  0.65372724, -0.40023798, -0.82362311,  0.58604708]),
#  array([ 1.45070785,  0.68389346, -0.40000675, -0.80209684,  0.5661686 ]),
#  array([ 1.46256427,  0.69878459, -0.4091496 , -0.80733852,  0.55360549]),
#  array([ 1.48635036,  0.65358921, -0.40007121, -0.79141439,  0.54646075]),
#  array([ 1.45800165,  0.66992472, -0.42459588, -0.75766198,  0.54904238]),
#  array([ 1.48683111,  0.68645396, -0.4086831 , -0.79368715,  0.52686682]),
#  array([ 1.47368176,  0.67128537, -0.4083447 , -0.79376002,  0.54907092]),
#  array([ 1.46420867,  0.6451613 , -0.39082971, -0.77967575,  0.55372005]),
#  array([ 1.48392689,  0.69299204, -0.40482706, -0.82488522,  0.5458037 ]),
#  array([ 1.4940836 ,  0.65957554, -0.41364049, -0.78797427,  0.54743147]),
#  array([ 1.49271995,  0.65494151, -0.42898511, -0.81244546,  0.58530768]),
#  array([ 1.45239553,  0.70148219, -0.41760308, -0.81221624,  0.57225083]),
#  array([ 1.48533057,  0.69233436, -0.41419297, -0.82941674,  0.56471508]),
#  array([ 1.47325718,  0.67701448, -0.38684716, -0.7935121 ,  0.52406451]),
#  array([ 1.44785169,  0.69869395, -0.41366981, -0.79998896,  0.56215231]),
#  array([ 1.45502105,  0.68369948, -0.42442853, -0.77415893,  0.553929  ]),
#  array([ 1.47595084,  0.6532655 , -0.39104882, -0.77540678,  0.53621982]),
#  array([ 1.49570741,  0.64071724, -0.42783489, -0.78409725,  0.56932712]),
#  array([ 1.48473825,  0.65897218, -0.38260928, -0.81703576,  0.54963118]),
#  array([ 1.48124955,  0.65546957, -0.40226825, -0.77840989,  0.53927849]),
#  array([ 1.4779412 ,  0.6499966 , -0.3497916 , -0.80819787,  0.52548518]),
#  array([ 1.46411952,  0.67811676, -0.40965389, -0.77952277,  0.54062406]),
#  array([ 1.47627159,  0.68112545, -0.3875642 , -0.80748115,  0.53511104]),
#  array([ 1.48092607,  0.65378083, -0.41699794, -0.78367542,  0.55791715]),
#  array([ 1.46461129,  0.67065946, -0.41221431, -0.80108564,  0.57212754]),
#  array([ 1.45632719,  0.670035  , -0.41493617, -0.7702186 ,  0.5570811 ]),
#  array([ 1.46283354,  0.65471656, -0.38778905, -0.78422294,  0.54878344]),
#  array([ 1.42808181,  0.64473455, -0.37761984, -0.75442494,  0.55254263]),
#  array([ 1.47789608,  0.68059172, -0.39767114, -0.84052234,  0.57087305]),
#  array([ 1.48149137,  0.6777213 , -0.41952291, -0.80560939,  0.55909829]),
#  array([ 1.46940611,  0.68145279, -0.4401057 , -0.79603045,  0.57742923]),
#  array([ 1.46918359,  0.64864744, -0.39362114, -0.81589147,  0.58769981]),
#  array([ 1.44740295,  0.66887103, -0.40942811, -0.76494131,  0.55536703]),
#  array([ 1.47586197,  0.66407289, -0.40965601, -0.8093487 ,  0.57299618]),
#  array([ 1.44442921,  0.66917299, -0.40656995, -0.75694206,  0.54457662]),
#  array([ 1.46463092,  0.64795269, -0.3900944 , -0.77992585,  0.55363269]),
#  array([ 1.49373633,  0.6940157 , -0.42830254, -0.80561043,  0.54717281]),
#  array([ 1.46521423,  0.64167361, -0.4100711 , -0.76278361,  0.56190049]),
#  array([ 1.45966027,  0.6599774 , -0.41925296, -0.77796794,  0.57456499]),
#  array([ 1.45668039,  0.64677265, -0.39668965, -0.76474775,  0.55410582]),
#  array([ 1.49225225,  0.63261121, -0.4013985 , -0.79837104,  0.57000104]),
#  array([ 1.48567852,  0.64946506, -0.42288206, -0.7933701 ,  0.57419144]),
#  array([ 1.49926624,  0.65142281, -0.42961559, -0.76841791,  0.53962951]),
#  array([ 1.45378917,  0.68847266, -0.40287732, -0.78366117,  0.53482769]),
#  array([ 1.45322489,  0.66306415, -0.3629606 , -0.8056295 ,  0.5461278 ]),
#  array([ 1.45982966,  0.68334356, -0.42182463, -0.77326772,  0.55163146]),
#  array([ 1.45769336,  0.66158122, -0.401553  , -0.7790497 ,  0.55668571]),
#  array([ 1.47875766,  0.67746075, -0.43092733, -0.76988828,  0.5400025 ]),
#  array([ 1.44452321,  0.67189612, -0.3754871 , -0.7881207 ,  0.54025079]),
#  array([ 1.46591401,  0.66144815, -0.40622728, -0.77307427,  0.54336788]),
#  array([ 1.50654853,  0.6534094 , -0.40586679, -0.81342049,  0.55437687]),
#  array([ 1.46170869,  0.66013128, -0.38889977, -0.80240085,  0.56423697]),
#  array([ 1.49563658,  0.65413315, -0.38613315, -0.79741177,  0.52874407]),
#  array([ 1.49148635,  0.67839304, -0.40646312, -0.80021696,  0.5328631 ]),
#  array([ 1.48803218,  0.68104251, -0.38960431, -0.8345608 ,  0.5525284 ]),
#  array([ 1.45316395,  0.66168427, -0.36489923, -0.78772129,  0.53479627]),
#  array([ 1.46072031,  0.67499492, -0.43848551, -0.76040827,  0.55968557]),
#  array([ 1.49819338,  0.65346961, -0.4143102 , -0.75665107,  0.51274349])]

# %%
10000*pd.DataFrame(result2.ASGD).cov()
# Out:
#           0         1         2         3         4
# 0  2.748128 -0.652026 -0.904021 -1.017568 -0.115959
# 1 -0.652026  3.024107 -0.914553 -0.826626 -0.592815
# 2 -0.904021 -0.914553  3.689254 -0.684278 -1.179713
# 3 -1.017568 -0.826626 -0.684278  3.457970 -0.955551
# 4 -0.115959 -0.592815 -1.179713 -0.955551  2.823445

# %%
true = np.repeat(5,5)
true= true.reshape(5,1)
true = np.dot(true,true.T)
true = true + np.eye(5)
true = np.linalg.inv(true)

# %%
true
# Out:
# array([[ 0.8015873, -0.1984127, -0.1984127, -0.1984127, -0.1984127],
#        [-0.1984127,  0.8015873, -0.1984127, -0.1984127, -0.1984127],
#        [-0.1984127, -0.1984127,  0.8015873, -0.1984127, -0.1984127],
#        [-0.1984127, -0.1984127, -0.1984127,  0.8015873, -0.1984127],
#        [-0.1984127, -0.1984127, -0.1984127, -0.1984127,  0.8015873]])
